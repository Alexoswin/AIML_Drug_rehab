# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexoswin/AIML_Drug_rehab/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/drug_rehab.csv")
df.head()
# Out:
#    Age  Gender Educated Living with Conflict with Law Criminal Record  \
# 0   28    Male      Yes      Family                No              No
# 1   35  Female      Yes     Friends               Yes             Yes
# 2   22  Others      Yes       Alone                No              No
# 3   40    Male       No      Family               Yes             Yes
# 4   31  Female      Yes     Friends                No              No
#
#   Spends Most Time With Failure in Life Mental/Emotional Problem  \
# 0                Family              No               Depression
# 1               Friends             Yes                  Anxiety
# 2                 Alone             Yes                    Anger
# 3                Family              No          Low Self-Esteem
# 4               Friends             Yes               Depression
#
#   Suicidal Thoughts  ... No. of Friends Satisfied with Workspace  \
# 0               Yes  ...             10                      Yes
# ...

# %%
# to drop any row that contains a value
df = df.drop(df[df["Age"] == 28 ].index)
df.head()
# Out:
#    Age  Gender Educated Living with Conflict with Law Criminal Record  \
# 1   35  Female      Yes     Friends               Yes             Yes
# 2   22  Others      Yes       Alone                No              No
# 3   40    Male       No      Family               Yes             Yes
# 4   31  Female      Yes     Friends                No              No
# 5   26    Male      Yes       Alone                No              No
#
#   Spends Most Time With Failure in Life Mental/Emotional Problem  \
# 1               Friends             Yes                  Anxiety
# 2                 Alone             Yes                    Anger
# 3                Family              No          Low Self-Esteem
# 4               Friends             Yes               Depression
# 5                 Alone             Yes               Depression
#
#   Suicidal Thoughts  ... No. of Friends Satisfied with Workspace  \
# 1               Yes  ...              5                       No
# ...

# %%
# to display a column in a row
df["Age" ]
# Out:
# 1      35
# 2      22
# 3      40
# 4      31
# 5      26
#        ..
# 491    12
# 492    16
# 493    18
# 494    14
# 495    16
# Name: Age, Length: 470, dtype: int64

# %%
#TO disolay any column whos head should be connected
df["Gender"].head(5)
# Out:
# 1    Female
# 2    Others
# 3      Male
# 4    Female
# 5      Male
# Name: Gender, dtype: object

# %%
# TO Replace a values or set of values of a column by another
df["Type of Drug Consumed"]= df["Type of Drug Consumed"].replace("Marijuana", "abc")
df["Type of Drug Consumed"]
# Out:
# 1               Heroin
# 2      Methamphetamine
# 3                  abc
# 4              Cocaine
# 5               Heroin
#             ...
# 491                abc
# 492                abc
# 493             Heroin
# 494                abc
# 495                abc
# Name: Type of Drug Consumed, Length: 470, dtype: object

# %%
# find count of isnull function and calculate the sum of the isnull in the column
print(" count of null values  in each column \n ", df.isnull().sum())
print()
print("sum of null values \n" , df.isnull().sum().sum())
# Out:
#  count of null values  in each column
#   Age                                 0
# Gender                              0
# Educated                            0
# Living with                         0
# Conflict with Law                   0
# Criminal Record                     0
# Spends Most Time With               0
# Failure in Life                     0
# Mental/Emotional Problem            0
# Suicidal Thoughts                   0
# Family Relation                     1
# Financial Status                    0
# Addicted Persons in Family          0
# No. of Friends                      0
# Satisfied with Workspace            0
# Living with Drug Consumer           0
# Smoking                             0
# Influenced By                       0
# Ease to Control Drug Use            0
# Frequency of Drug Usage per Week    0
# Days Taken to Get Cure              0
# City                                0
# Type of Drug Consumed               0
# dtype: int64
#
# sum of null values
# ...

# %%
# to find outliners in  a column
df["Type of Drug Consumed"].describe()
# Out:
# count     470
# unique     18
# top       abc
# freq       74
# Name: Type of Drug Consumed, dtype: object

# %%
# drop a row which contains nan values
df = df.dropna()

# %%
# to set the first column as the index for the rows
df = df.set_index("Age")
df.head()
# Out:
#      Gender Educated Living with Conflict with Law Criminal Record  \
# Age
# 35   Female      Yes     Friends               Yes             Yes
# 22   Others      Yes       Alone                No              No
# 40     Male       No      Family               Yes             Yes
# 31   Female      Yes     Friends                No              No
# 26     Male      Yes       Alone                No              No
#
#     Spends Most Time With Failure in Life Mental/Emotional Problem  \
# Age
# 35                Friends             Yes                  Anxiety
# 22                  Alone             Yes                    Anger
# 40                 Family              No          Low Self-Esteem
# 31                Friends             Yes               Depression
# 26                  Alone             Yes               Depression
#
#     Suicidal Thoughts Family Relation  ... No. of Friends  \
# Age                                    ...
# ...

# %%
# set a group of columns as indexes
df = df.set_index(["Frequency of Drug Usage per Week","Days Taken to Get Cure"])

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-255ead8ec66a> in <cell line: 2>()
#       1 # set a group of columns as indexes
# ----> 2 df = df.set_index(["Frequency of Drug Usage per Week","Days Taken to Get Cure"])
#       3
#       4 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# ...

# %%
import pandas as pd

dfnew = pd.DataFrame({'name': ['oswin', "Alex", 'sad', "Sdds"], "age": [43, 23, 12, 65]})
dfnew['age']
# Out:
# 0    43
# 1    23
# 2    12
# 3    65
# Name: age, dtype: int64

# %%
#display all nan values
df.isnull()
# Out:
#                                                          Gender  Educated  \
# Frequency of Drug Usage per Week Days Taken to Get Cure
# 5                                90                       False     False
# 2                                45                       False     False
# 4                                75                       False     False
# 6                                100                      False     False
# 2                                40                       False     False
# ...                                                         ...       ...
# 5                                80                       False     False
# 7                                105                      False     False
# 3                                45                       False     False
# 4                                60                       False     False
# 2                                35                       False     False
#
# ...

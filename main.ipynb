# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexoswin/AIML_Drug_rehab/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
path ="/content/Book1.csv"
df = pd.read_csv(path)
df.head()
# Out:
#     Age  Gender Educated Living with Conflict with Law Criminal Record  \
# 0  28.0    Male      Yes      Family                No              No
# 1  35.0  Female      Yes     Friends               Yes             Yes
# 2  22.0    Male      Yes       Alone                No              No
# 3  40.0    Male       No      Family               Yes             Yes
# 4  31.0    Male      Yes     Friends                No              No
#
#   Spends Most Time With Failure in Life Mental/Emotional Problem  \
# 0                Family              No               Depression
# 1               Friends             Yes                  Anxiety
# 2                 Alone             Yes                    Anger
# 3                Family              No          Low Self-Esteem
# 4               Friends             Yes               Depression
#
#   Suicidal Thoughts  ... No. of Friends Satisfied with Workspace  \
# 0               Yes  ...           10.0                      Yes
# 1               Yes  ...            5.0                       No
# 2               Yes  ...            8.0                      Yes
# 3               Yes  ...            6.0                      Yes
# 4               Yes  ...            0.0                      Yes
#
#   Living with Drug Consumer  Smoking  Influenced By Ease to Control Drug Use  \
# 0                       Yes      Yes  Peer Pressure                      Yes
# 1                        No       No         Stress                       No
# 2                       Yes      Yes         Trauma                      Yes
# 3                        No      Yes         Stress                       No
# 4                       Yes      Yes  Peer Pressure                      Yes
#
#   Frequency of Drug Usage per Week Days Taken to Get Cure     City  \
# 0                              3.0                   60.0   Mumbai
# 1                              5.0                   90.0    Delhi
# 2                              2.0                   45.0  Kolkata
# 3                              4.0                   75.0  Chennai
# 4                              6.0                  100.0   Mumbai
#
#    Type of Drug Consumed
# 0                Cocaine
# 1                 Heroin
# 2        Methamphetamine
# 3              Marijuana
# 4                Cocaine
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#               Age  No. of Friends  Frequency of Drug Usage per Week  \
# count  652.000000      652.000000                        652.000000
# mean    39.884969        5.124233                         11.285276
# std     13.148471        4.239551                          8.788603
# min      7.000000        0.000000                          1.000000
# 25%     29.000000        2.000000                          4.000000
# 50%     36.000000        5.000000                          7.000000
# 75%     55.000000        8.000000                         18.250000
# max     62.000000       20.000000                         35.000000
#
#        Days Taken to Get Cure
# count              652.000000
# mean               102.957055
# std                 53.356247
# min                 20.000000
# 25%                 70.000000
# 50%                 90.000000
# 75%                120.000000
# max                655.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653 entries, 0 to 652
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               652 non-null    float64
#  1   Gender                            652 non-null    object
#  2   Educated                          652 non-null    object
#  3   Living with                       652 non-null    object
#  4   Conflict with Law                 652 non-null    object
#  5   Criminal Record                   652 non-null    object
#  6   Spends Most Time With             652 non-null    object
#  7   Failure in Life                   652 non-null    object
#  8   Mental/Emotional Problem          652 non-null    object
#  9   Suicidal Thoughts                 652 non-null    object
#  10  Family Relation                   652 non-null    object
#  11  Financial Status                  652 non-null    object
#  12  Addicted Persons in Family        652 non-null    object
#  13  No. of Friends                    652 non-null    float64
#  14  Satisfied with Workspace          652 non-null    object
#  15  Living with Drug Consumer         652 non-null    object
#  16  Smoking                           652 non-null    object
#  17  Influenced By                     650 non-null    object
#  18  Ease to Control Drug Use          652 non-null    object
#  19  Frequency of Drug Usage per Week  652 non-null    float64
#  20  Days Taken to Get Cure            652 non-null    float64
#  21  City                              652 non-null    object
#  22  Type of Drug Consumed             652 non-null    object
# dtypes: float64(4), object(19)
# memory usage: 117.5+ KB

# %%
# ----- pandas and numpy tutorial ----
dates = pd.date_range("20130101", periods =6)
print(dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2 = pd.DataFrame(
    {
      "A" : 1.0,
      "B" : pd.date_range("20230101" , periods = 10 ) ,
      "C" : pd.Series(1 , index= list(range(10)), dtype = "float32"),
      "D" : np.array([3,4,6,1,9,2,9,3,6,8] *1, dtype= "int32"),
      "E" : pd.Categorical(["test" ,"train", "test", "train","test" ,"train", "test", "train","test" ,"train"]),
      "F" : ["foo","ffa", "dsa","sfa","WDD","foo","ffa", "dsa","sfa","WDD"]
    }
)

# %%
print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-01-01  1.0  3   test  foo
# 1  1.0 2023-01-02  1.0  4  train  ffa
# 2  1.0 2023-01-03  1.0  6   test  dsa
# 3  1.0 2023-01-04  1.0  1  train  sfa
# 4  1.0 2023-01-05  1.0  9   test  WDD
# 5  1.0 2023-01-06  1.0  2  train  foo
# 6  1.0 2023-01-07  1.0  9   test  ffa
# 7  1.0 2023-01-08  1.0  3  train  dsa
# 8  1.0 2023-01-09  1.0  6   test  sfa
# 9  1.0 2023-01-10  1.0  8  train  WDD

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df2.to_numpy()
# represents dataset in the form of array
# Out:
# array([[1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-01-02 00:00:00'), 1.0, 4, 'train', 'ffa'],
#        [1.0, Timestamp('2023-01-03 00:00:00'), 1.0, 6, 'test', 'dsa'],
#        [1.0, Timestamp('2023-01-04 00:00:00'), 1.0, 1, 'train', 'sfa'],
#        [1.0, Timestamp('2023-01-05 00:00:00'), 1.0, 9, 'test', 'WDD'],
#        [1.0, Timestamp('2023-01-06 00:00:00'), 1.0, 2, 'train', 'foo'],
#        [1.0, Timestamp('2023-01-07 00:00:00'), 1.0, 9, 'test', 'ffa'],
#        [1.0, Timestamp('2023-01-08 00:00:00'), 1.0, 3, 'train', 'dsa'],
#        [1.0, Timestamp('2023-01-09 00:00:00'), 1.0, 6, 'test', 'sfa'],
#        [1.0, Timestamp('2023-01-10 00:00:00'), 1.0, 8, 'train', 'WDD']],
#       dtype=object)

# %%
df2.T
# transposing your data
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2023-01-01 00:00:00  2023-01-02 00:00:00  2023-01-03 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    4                    6
# E                 test                train                 test
# F                  foo                  ffa                  dsa
#
#                      3                    4                    5  \
# A                  1.0                  1.0                  1.0
# B  2023-01-04 00:00:00  2023-01-05 00:00:00  2023-01-06 00:00:00
# C                  1.0                  1.0                  1.0
# D                    1                    9                    2
# E                train                 test                train
# F                  sfa                  WDD                  foo
#
#                      6                    7                    8  \
# A                  1.0                  1.0                  1.0
# B  2023-01-07 00:00:00  2023-01-08 00:00:00  2023-01-09 00:00:00
# C                  1.0                  1.0                  1.0
# D                    9                    3                    6
# E                 test                train                 test
# F                  ffa                  dsa                  sfa
#
#                      9
# A                  1.0
# B  2023-01-10 00:00:00
# C                  1.0
# D                    8
# E                train
# F                  WDD

# %%
df2.sort_index(axis =1, ascending=False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2023-01-01  1.0
# 1  ffa  train  4  1.0 2023-01-02  1.0
# 2  dsa   test  6  1.0 2023-01-03  1.0
# 3  sfa  train  1  1.0 2023-01-04  1.0
# 4  WDD   test  9  1.0 2023-01-05  1.0
# 5  foo  train  2  1.0 2023-01-06  1.0
# 6  ffa   test  9  1.0 2023-01-07  1.0
# 7  dsa  train  3  1.0 2023-01-08  1.0
# 8  sfa   test  6  1.0 2023-01-09  1.0
# 9  WDD  train  8  1.0 2023-01-10  1.0
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['E'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['D'].plot(kind='hist', bins=20, title='D')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('F').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['B']
#   ys = series['D']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('B', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('F')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='F', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('B')
# _ = plt.ylabel('D')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['B']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'B'}, axis=1)
#               .sort_values('B', ascending=True))
#   xs = counted['B']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('B', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('F')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='F', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('B')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['C']
#   ys = series['D']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('C', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('F')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='F', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('C')
# _ = plt.ylabel('D')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['C']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'C'}, axis=1)
#               .sort_values('C', ascending=True))
#   xs = counted['C']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('C', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('F')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='F', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('C')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['D'].plot(kind='line', figsize=(8, 4), title='D')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_7['F'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_7, x='D', y='F', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df2.sort_values(by ="D")
# Out:
#      A          B    C  D      E    F
# 3  1.0 2023-01-04  1.0  1  train  sfa
# 5  1.0 2023-01-06  1.0  2  train  foo
# 0  1.0 2023-01-01  1.0  3   test  foo
# 7  1.0 2023-01-08  1.0  3  train  dsa
# 1  1.0 2023-01-02  1.0  4  train  ffa
# 2  1.0 2023-01-03  1.0  6   test  dsa
# 8  1.0 2023-01-09  1.0  6   test  sfa
# 9  1.0 2023-01-10  1.0  8  train  WDD
# 4  1.0 2023-01-05  1.0  9   test  WDD
# 6  1.0 2023-01-07  1.0  9   test  ffa

# %%
df.sort_values(by = "Frequency of Drug Usage per Week" and "Age" and "Days Taken to Get Cure" and "No. of Friends" )
# sorting
# Out:
#       Age Gender Educated Living with Conflict with Law Criminal Record  \
# 652  58.0   Male      Yes       Alone                No              No
# 554  59.0   Male      Yes      Family                No              No
# 186  28.0   Male      Yes      Family                No             Yes
# 553  49.0   Male      Yes       Alone               Yes              No
# 552  57.0   Male       No       Alone                No              No
# ..    ...    ...      ...         ...               ...             ...
# 193  29.0   Male       No     Friends                No              No
# 163  29.0   Male       No     Friends                No              No
# 281  27.0   Male       No     Friends                No              No
# 131  32.0   Male       No     Friends                No              No
# 444   NaN    NaN      NaN         NaN               NaN             NaN
#
#     Spends Most Time With Failure in Life Mental/Emotional Problem  \
# 652                Family              No               Depression
# 554                Family              No               Depression
# 186                Family              No               Depression
# 553                 Alone              No               Depression
# 552                 Alone             Yes               Depression
# ..                    ...             ...                      ...
# 193               Friends              No              No Problems
# 163               Friends              No              No Problems
# 281               Friends              No              No Problems
# 131               Friends              No               Depression
# 444                   NaN             NaN                      NaN
#
#     Suicidal Thoughts  ... No. of Friends Satisfied with Workspace  \
# 652               Yes  ...            0.0                       No
# 554               Yes  ...            0.0                       No
# 186               Yes  ...            0.0                      Yes
# 553               Yes  ...            0.0                      Yes
# 552               Yes  ...            0.0                       No
# ..                ...  ...            ...                      ...
# 193                No  ...           20.0                       No
# 163                No  ...           20.0                       No
# 281                No  ...           20.0                       No
# 131               Yes  ...           20.0                       No
# 444               NaN  ...            NaN                      NaN
#
#     Living with Drug Consumer  Smoking  Influenced By  \
# 652                        No       No      Curiosity
# 554                        No       No      Curiosity
# 186                        No      Yes      Curiosity
# 553                       Yes      Yes     Depression
# 552                        No       No  Peer Pressure
# ..                        ...      ...            ...
# 193                       Yes       No        Friends
# 163                       Yes       No        Friends
# 281                       Yes       No        Friends
# 131                        No      Yes        Friends
# 444                       NaN      NaN            NaN
#
#     Ease to Control Drug Use Frequency of Drug Usage per Week  \
# 652                      Yes                              5.0
# 554                      Yes                              4.0
# 186                       No                             15.0
# 553                      Yes                              5.0
# 552                      Yes                              1.0
# ..                       ...                              ...
# 193                       No                             12.0
# 163                       No                             12.0
# 281                       No                             12.0
# 131                       No                             18.0
# 444                      NaN                              NaN
#
#     Days Taken to Get Cure       City  Type of Drug Consumed
# 652                   30.0    Aligarh                 Heroin
# 554                   70.0      Delhi                 Heroin
# 186                   90.0     Mumbai                Cocaine
# 553                   85.0     Mumbai                Cocaine
# 552                   30.0      Delhi              Marijuana
# ..                     ...        ...                    ...
# 193                   90.0  Ahmedabad          Crack Cocaine
# 163                   90.0  Ahmedabad          Crack Cocaine
# 281                   90.0  Ahmedabad          Crack Cocaine
# 131                  120.0  Ahmedabad          Crack Cocaine
# 444                    NaN        NaN                    NaN
#
# [653 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['No. of Friends'].plot(kind='hist', bins=20, title='No. of Friends')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Frequency of Drug Usage per Week'].plot(kind='hist', bins=20, title='Frequency of Drug Usage per Week')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Days Taken to Get Cure'].plot(kind='hist', bins=20, title='Days Taken to Get Cure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_13.groupby('Educated').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_14.groupby('Living with').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_15.groupby('Conflict with Law').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='Age', y='No. of Friends', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='No. of Friends', y='Frequency of Drug Usage per Week', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='Frequency of Drug Usage per Week', y='Days Taken to Get Cure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['No. of Friends'].plot(kind='line', figsize=(8, 4), title='No. of Friends')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['Frequency of Drug Usage per Week'].plot(kind='line', figsize=(8, 4), title='Frequency of Drug Usage per Week')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['Days Taken to Get Cure'].plot(kind='line', figsize=(8, 4), title='Days Taken to Get Cure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Educated'].value_counts()
#     for x_label, grp in _df_23.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Educated')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Living with'].value_counts()
#     for x_label, grp in _df_24.groupby('Educated')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Educated')
# _ = plt.ylabel('Living with')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Conflict with Law'].value_counts()
#     for x_label, grp in _df_25.groupby('Living with')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Living with')
# _ = plt.ylabel('Conflict with Law')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Criminal Record'].value_counts()
#     for x_label, grp in _df_26.groupby('Conflict with Law')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Conflict with Law')
# _ = plt.ylabel('Criminal Record')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='Age', y='Gender', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_28['Educated'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_28, x='Age', y='Educated', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_29['Living with'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_29, x='Age', y='Living with', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_30['Conflict with Law'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_30, x='Age', y='Conflict with Law', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df2["B"]
# Out:
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# 5   2023-01-06
# 6   2023-01-07
# 7   2023-01-08
# 8   2023-01-09
# 9   2023-01-10
# Name: B, dtype: datetime64[ns]

# %%
df[100:105]
# Out:
#       Age  Gender Educated Living with Conflict with Law Criminal Record  \
# 100  24.0  Others       No     Friends                No              No
# 101  30.0    Male      Yes       Alone                No              No
# 102  27.0  Female      Yes     Friends               Yes             Yes
# 103  32.0    Male      Yes      Family                No              No
# 104  29.0  Female      Yes       Alone               Yes              No
#
#     Spends Most Time With Failure in Life Mental/Emotional Problem  \
# 100               Friends             Yes                    Anger
# 101                 Alone             Yes          Low Self-esteem
# 102                 Alone             Yes                  Anxiety
# 103                 Alone              No               Depression
# 104               Friends             Yes                  Anxiety
#
#     Suicidal Thoughts  ... No. of Friends Satisfied with Workspace  \
# 100                No  ...            5.0                       No
# 101               Yes  ...            2.0                      Yes
# 102               Yes  ...            8.0                      Yes
# 103               Yes  ...            4.0                      Yes
# 104               Yes  ...            0.0                       No
#
#     Living with Drug Consumer  Smoking  Influenced By  \
# 100                       Yes      Yes         Family
# 101                        No      Yes          Media
# 102                        No       No          Peers
# 103                       Yes      Yes         Family
# 104                        No       No  Peer Pressure
#
#     Ease to Control Drug Use Frequency of Drug Usage per Week  \
# 100                       No                              9.0
# 101                      Yes                              4.0
# 102                      Yes                              9.0
# 103                      Yes                              6.0
# 104                       No                              6.0
#
#     Days Taken to Get Cure       City  Type of Drug Consumed
# 100                   60.0  Bangalore        Methamphetamine
# 101                  120.0    Chennai               Cannabis
# 102                  150.0    Kolkata                   MDMA
# 103                   90.0      Delhi                Cocaine
# 104                  180.0     Mumbai                 Heroin
#
# [5 rows x 23 columns]

# %%
df2.loc[:, ["A" , "F"]]
# Out:
#      A    F
# 0  1.0  foo
# 1  1.0  ffa
# 2  1.0  dsa
# 3  1.0  sfa
# 4  1.0  WDD
# 5  1.0  foo
# 6  1.0  ffa
# 7  1.0  dsa
# 8  1.0  sfa
# 9  1.0  WDD
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('F').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['A']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'A'}, axis=1)
#               .sort_values('A', ascending=True))
#   xs = counted['A']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('A', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('F')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='F', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('A')
# _ = plt.ylabel('count()')

# %%
df.loc[: , ["Age", "Days Taken to Get Cure"]]
# Out:
#       Age  Days Taken to Get Cure
# 0    28.0                    60.0
# 1    35.0                    90.0
# 2    22.0                    45.0
# 3    40.0                    75.0
# 4    31.0                   100.0
# ..    ...                     ...
# 648  56.0                    42.0
# 649  57.0                    35.0
# 650  58.0                    95.0
# 651  59.0                    36.0
# 652  58.0                    30.0
#
# [653 rows x 2 columns]

# %%
df.loc[100:110,["Age", "Days Taken to Get Cure"]]
# Out:
#       Age  Days Taken to Get Cure
# 100  24.0                    60.0
# 101  30.0                   120.0
# 102  27.0                   150.0
# 103  32.0                    90.0
# 104  29.0                   180.0
# 105  26.0                    60.0
# 106  33.0                   120.0
# 107  31.0                   150.0
# 108  34.0                   120.0
# 109  23.0                    90.0
# 110  36.0                   180.0

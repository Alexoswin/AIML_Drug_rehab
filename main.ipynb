# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexoswin/AIML_Drug_rehab/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

path ="/content/drugAddiction.csv"
df = pd.read_csv(path,  encoding='latin-1')

# %%
df.head(10)
# Out:
#                       Age Gender         Education Enjoyable with-  \
# 0  between 22 to 35 years   Male     Undergraduate        One drug
# 1  between 22 to 35 years   Male  H.S.C / A levels  I have no idea
# 2          15 to 22 years   Male  H.S.C / A levels        One drug
# 3  between 22 to 35 years   Male     Undergraduate        One drug
# 4  between 22 to 35 years   Male     Undergraduate  I have no idea
# 5  between 22 to 35 years   Male     Undergraduate  I have no idea
# 6  between 22 to 35 years   Male     Undergraduate  I have no idea
# 7  between 22 to 35 years   Male     Undergraduate  Multiple drugs
# 8  between 22 to 35 years   Male     Undergraduate  I have no idea
# 9  between 22 to 35 years   Male     Undergraduate        One drug
#
#                Live with Conflict with law           Motive about drug  \
# 0            Hostel/Hall                No                     Disease
# 1  With Family/Relatives               Yes                Should avoid
# 2  With Family/Relatives               Yes                     Disease
# 3  With Family/Relatives                No                Social trend
# 4  With Family/Relatives                No  Social trend, Should avoid
# 5  With Family/Relatives                No  Social trend, Should avoid
# 6  With Family/Relatives                No  Social trend, Should avoid
# 7  With Family/Relatives                No                Should avoid
# 8  With Family/Relatives                No                Should avoid
# 9            Hostel/Hall                No                     Disease
#
#   Spend most time Failure in life  \
# 0           Alone             Yes
# 1         Friends             Yes
# 2         Friends             Yes
# 3         Friends             Yes
# 4           Alone              No
# 5           Alone              No
# 6           Alone              No
# 7         Friends             Yes
# 8         Friends             Yes
# 9           Alone             Yes
#
#                             Mental/emotional problem  ...  \
# 0                      Depression/ inferiority/Guilt  ...
# 1  Depression/ inferiority/Guilt, Tension/Anxiety...  ...
# 2                      Depression/ inferiority/Guilt  ...
# 3  Depression/ inferiority/Guilt, Tension/Anxiety...  ...
# 4  Depression/ inferiority/Guilt, Tension/Anxiety...  ...
# 5  Depression/ inferiority/Guilt, Tension/Anxiety...  ...
# 6  Depression/ inferiority/Guilt, Tension/Anxiety...  ...
# 7                                    Tension/Anxiety  ...
# 8                      Depression/ inferiority/Guilt  ...
# 9                      Depression/ inferiority/Guilt  ...
#
#   friends houses at night Satisfied with workplace Case in court  \
# 0              No, I don't                       No            No
# 1                Sometimes                       No            No
# 2                Sometimes                       No           Yes
# 3                Sometimes                      Yes            No
# 4                Sometimes                      Yes            No
# 5                Sometimes                      Yes            No
# 6                Sometimes                      Yes            No
# 7         Yes, often I do.                      Yes            No
# 8                Sometimes                       No            No
# 9                Sometimes                       No            No
#
#   Living with drug user            Smoking Ever taken drug  \
# 0                   Yes    Yes, every day.             Yes
# 1                    No    Yes, every day.             Yes
# 2                   Yes    Yes, every day.             Yes
# 3                   Yes    Yes, every day.             Yes
# 4                    No    Yes, every day.              No
# 5                    No    Yes, every day.              No
# 6                    No    Yes, every day.              No
# 7                    No    Yes, every day.             Yes
# 8                    No    Yes, every day.             Yes
# 9                    No  Yes, occasionally              No
#
#     Friends influence If chance given to taste drugs  \
# 0  Yes, often they do                       I'll try
# 1  Yes, often they do         i don't know/ confused
# 2  Yes, often they do                       I'll try
# 3  Yes, often they do                       I'll try
# 4      No, they don't                   no, i'll not
# 5      No, they don't                   no, i'll not
# 6      No, they don't                   no, i'll not
# 7  Yes, often they do                       I'll try
# 8  Yes, often they do         i don't know/ confused
# 9  Yes, often they do         i don't know/ confused
#
#   Easy to control use of drug Frequency of drug usage
# 0          Yes, It's possible       Once/twice a week
# 1          Yes, It's possible            Occasionally
# 2       No, It's not possible       Once/twice a week
# 3          Yes, It's possible       Once/twice a week
# 4          Yes, It's possible   Never/ Not applicable
# 5          Yes, It's possible   Never/ Not applicable
# 6          Yes, It's possible   Never/ Not applicable
# 7          Yes, It's possible            Occasionally
# 8          Yes, It's possible            Occasionally
# 9       No, It's not possible            Occasionally
#
# [10 rows x 26 columns]

# %%
df.tail(5)
# Out:
#                         Age  Gender               Education Enjoyable with-  \
# 206  between 22 to 35 years    Male           Undergraduate        One drug
# 207  between 22 to 35 years    Male           Undergraduate        One drug
# 208  between 22 to 35 years    Male  Postgraduate (MSc/PhD)        One drug
# 209  between 22 to 35 years  Female  Postgraduate (MSc/PhD)  I have no idea
# 210  between 22 to 35 years  Female           Undergraduate  I have no idea
#
#                  Live with Conflict with law      Motive about drug  \
# 206            Hostel/Hall                No           Social trend
# 207            Hostel/Hall               Yes           Social trend
# 208            Hostel/Hall                No           Social trend
# 209  With Family/Relatives                No  Disease, Should avoid
# 210            Hostel/Hall                No           Should avoid
#
#        Spend most time Failure in life  \
# 206            Friends             Yes
# 207            Friends              No
# 208              Alone             Yes
# 209  Family/ Relatives              No
# 210              Alone             Yes
#
#                               Mental/emotional problem  ...  \
# 206                      Depression/ inferiority/Guilt  ...
# 207                                              Anger  ...
# 208                                    Tension/Anxiety  ...
# 209                                    Tension/Anxiety  ...
# 210  Depression/ inferiority/Guilt, Tension/Anxiety...  ...
#
#     friends houses at night Satisfied with workplace Case in court  \
# 206         Yes, often I do.                       No            No
# 207                Sometimes                      Yes            No
# 208                Sometimes                       No            No
# 209                Sometimes                      Yes            No
# 210              No, I don't                       No            No
#
#     Living with drug user          Smoking Ever taken drug  \
# 206                    No  Yes, every day.             Yes
# 207                    No  Yes, every day.             Yes
# 208                    No  Yes, every day.             Yes
# 209                    No      No, I don't              No
# 210                    No      No, I don't              No
#
#       Friends influence If chance given to taste drugs  \
# 206  Yes, often they do                       I'll try
# 207  Yes, often they do                       I'll try
# 208  Yes, often they do                       I'll try
# 209      No, they don't                   no, i'll not
# 210      No, they don't         i don't know/ confused
#
#     Easy to control use of drug Frequency of drug usage
# 206          Yes, It's possible   Never/ Not applicable
# 207          Yes, It's possible            Occasionally
# 208          Yes, It's possible            Occasionally
# 209          Yes, It's possible   Never/ Not applicable
# 210          Yes, It's possible   Never/ Not applicable
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             211 non-null    object
#  1   Gender                          211 non-null    object
#  2   Education                       211 non-null    object
#  3   Enjoyable with-                 211 non-null    object
#  4   Live with                       211 non-null    object
#  5   Conflict with law               211 non-null    object
#  6   Motive about drug               211 non-null    object
#  7   Spend most time                 211 non-null    object
#  8   Failure in life                 211 non-null    object
#  9   Mental/emotional problem        211 non-null    object
#  10  Suicidal thoughts               211 non-null    object
#  11  Family relationship             211 non-null    object
#  12  Financials of family            211 non-null    object
#  13  Addicted person in family       211 non-null    object
#  14  no. of friends                  211 non-null    object
#  15  Withdrawal symptoms             211 non-null    object
#  16  friends houses at night        211 non-null    object
#  17  Satisfied with workplace        211 non-null    object
#  18  Case in court                   211 non-null    object
#  19  Living with drug user           211 non-null    object
#  20  Smoking                         211 non-null    object
#  21  Ever taken drug                 211 non-null    object
#  22  Friends influence               211 non-null    object
#  23  If chance given to taste drugs  211 non-null    object
#  24  Easy to control use of drug     211 non-null    object
#  25  Frequency of drug usage         211 non-null    object
# dtypes: object(26)
# memory usage: 43.0+ KB

# %%
df.size
# Out:
# 5486

# %%
# removing empty values
df_new =df.dropna()

# %%
df_new.size
# Out:
# 5486

# %%
df.describe()
# Out:
#                            Age Gender      Education Enjoyable with-  \
# count                      211    211            211             211
# unique                       4      2              5               3
# top     between 22 to 35 years   Male  Undergraduate  I have no idea
# freq                       122    142            132             122
#
#                     Live with Conflict with law Motive about drug  \
# count                     211               211               211
# unique                      2                 2                 7
# top     With Family/Relatives                No      Should avoid
# freq                      130               159                83
#
#        Spend most time Failure in life       Mental/emotional problem  ...  \
# count              211             211                            211  ...
# unique               3               2                             17  ...
# top            Friends             Yes  Depression/ inferiority/Guilt  ...
# freq               127             109                             44  ...
#
#        friends houses at night Satisfied with workplace Case in court  \
# count                       211                      211           211
# unique                        3                        2             2
# top                   Sometimes                      Yes            No
# freq                        111                      132           184
#
#        Living with drug user          Smoking Ever taken drug  \
# count                    211              211             211
# unique                     3                3               2
# top                       No  Yes, every day.              No
# freq                     125               90             114
#
#        Friends influence If chance given to taste drugs  \
# count                211                            211
# unique                 2                              3
# top       No, they don't                   no, i'll not
# freq                 134                             83
#
#        Easy to control use of drug Frequency of drug usage
# count                          211                     211
# unique                           2                       4
# top             Yes, It's possible   Never/ Not applicable
# freq                           157                     110
#
# [4 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split
